# %% [markdown]
# # Module 1 - Feature Extraction, Dimensionality Reduction, Feature Ranking

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
data_dir = r'C:\Users\alexa\Documents\GeorgiaTech\Classes\Year4\CS4641'
datasets = os.listdir(data_dir)
print(datasets)
# Out:
# ['US_Accidents_Dec19.csv', 'US_WeatherEvents_2016-2019.csv']

# %%
df = pd.read_csv(data_dir + '\\' + datasets[0])

# %%
print(df.shape)
print(df.dtypes)
# print(df.describe())
df.head()
# Out:
# (2974335, 49)
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# dtype: object
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng          ...           Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          ...                False
# 1  39.928059 -82.831184      NaN      NaN          ...                False
# 2  39.063148 -84.032608      NaN      NaN          ...                False
# 3  39.747753 -84.205582      NaN      NaN          ...                False
# 4  39.627781 -84.188354      NaN      NaN          ...                False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Extract Labels

# %%
y = df['Severity']
y = np.reshape(y, (y.shape[0], 1))
# Out:
# C:\Users\alexa\AppData\Local\Programs\Python\Python36\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
print(y.shape)
print(stats.describe(y))
# Out:
# (2974335, 1)
# DescribeResult(nobs=2974335, minmax=(array([1], dtype=int64), array([4], dtype=int64)), mean=array([2.36019009]), variance=array([0.29319336]), skewness=array([1.15215415]), kurtosis=array([0.33720334]))

# %% [markdown]
# ## Drop Some Features

# %%
bad_features = ['ID', 'Source', 'TMC', 'End_Lat', 'End_Lng', 'Description', 'Number', 'Street', 'Side', 'County', 'Zipcode', 'Country', 'Timezone', 'Airport_Code']
#keep City and State, use to select data to focus on
#TMC could be useful but 1/4 are missing

X = df.drop('Severity', 1) #this will be our supervised label
X = X.drop(bad_features, 1)

# %%
print(X.shape)
print(X.dtypes)
X.head()
# Out:
# (2974335, 34)
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# City                      object
# State                     object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# dtype: object
#             Start_Time             End_Time  Start_Lat  Start_Lng  \
# 0  2016-02-08 05:46:00  2016-02-08 11:00:00  39.865147 -84.058723
# 1  2016-02-08 06:07:59  2016-02-08 06:37:59  39.928059 -82.831184
# 2  2016-02-08 06:49:27  2016-02-08 07:19:27  39.063148 -84.032608
# 3  2016-02-08 07:23:34  2016-02-08 07:53:34  39.747753 -84.205582
# 4  2016-02-08 07:39:07  2016-02-08 08:09:07  39.627781 -84.188354
#
#    Distance(mi)          City State    Weather_Timestamp  Temperature(F)  \
# 0          0.01        Dayton    OH  2016-02-08 05:58:00            36.9
# 1          0.01  Reynoldsburg    OH  2016-02-08 05:51:00            37.9
# 2          0.01  Williamsburg    OH  2016-02-08 06:56:00            36.0
# 3          0.01        Dayton    OH  2016-02-08 07:38:00            35.1
# 4          0.01        Dayton    OH  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)          ...            Roundabout  Station   Stop  \
# 0            NaN          ...                 False    False  False
# 1            NaN          ...                 False    False  False
# 2           33.3          ...                 False    False  False
# 3           31.0          ...                 False    False  False
# 4           33.3          ...                 False    False  False
#
#   Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0           False           False         False          Night
# 1           False           False         False          Night
# 2           False            True         False          Night
# 3           False           False         False          Night
# 4           False            True         False            Day
#
#    Civil_Twilight  Nautical_Twilight  Astronomical_Twilight
# 0           Night              Night                  Night
# 1           Night              Night                    Day
# 2           Night                Day                    Day
# 3             Day                Day                    Day
# 4             Day                Day                    Day
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Fill In Missing Data

# %%
X.isnull().sum()
# Out:
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# City                          83
# State                          0
# Weather_Timestamp          36705
# Temperature(F)             56063
# Wind_Chill(F)            1852623
# Humidity(%)                59173
# Pressure(in)               48142
# Visibility(mi)             65691
# Wind_Direction             45101
# Wind_Speed(mph)           440840
# Precipitation(in)        1998358
# Weather_Condition          65932
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                93
# Civil_Twilight                93
# Nautical_Twilight             93
# Astronomical_Twilight         93
# dtype: int64

# %%
def impute_median(series):
    return series.fillna(series.median())

# %%
#fill in missing numerical data

X['Temperature(F)'] = X['Temperature(F)'].transform(impute_median)
X['Wind_Chill(F)'] = X['Wind_Chill(F)'].transform(impute_median)
X['Humidity(%)'] = X['Humidity(%)'].transform(impute_median)
X['Pressure(in)'] = X['Pressure(in)'].transform(impute_median)
X['Visibility(mi)'] = X['Visibility(mi)'].transform(impute_median)
X['Wind_Speed(mph)'] = X['Wind_Speed(mph)'].transform(impute_median)
X['Precipitation(in)'] = X['Precipitation(in)'].transform(impute_median)

# %%
X.isnull().sum()
# Out:
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# City                        83
# State                        0
# Weather_Timestamp        36705
# Temperature(F)               0
# Wind_Chill(F)                0
# Humidity(%)                  0
# Pressure(in)                 0
# Visibility(mi)               0
# Wind_Direction           45101
# Wind_Speed(mph)              0
# Precipitation(in)            0
# Weather_Condition        65932
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# Railway                      0
# Roundabout                   0
# Station                      0
# Stop                         0
# Traffic_Calming              0
# Traffic_Signal               0
# Turning_Loop                 0
# Sunrise_Sunset              93
# Civil_Twilight              93
# Nautical_Twilight           93
# Astronomical_Twilight       93
# dtype: int64

# %%
print(X.dtypes)
# Out:
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# City                      object
# State                     object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# dtype: object

# %%
#fill in missing categorical data with mode

# print(X['Side'].mode())
print(X['City'].mode())
print(X['State'].mode())
print(X['Weather_Timestamp'].mode())
print(X['Wind_Direction'].mode())
print(X['Weather_Condition'].mode())
print(X['Sunrise_Sunset'].mode())
print(X['Civil_Twilight'].mode())
print(X['Nautical_Twilight'].mode())
print(X['Astronomical_Twilight'].mode())
# Out:
# 0    Houston
# dtype: object
# 0    CA
# dtype: object
# 0    2019-09-17 07:53:00
# 1    2019-09-24 07:53:00
# dtype: object
# 0    Calm
# dtype: object
# 0    Clear
# dtype: object
# 0    Day
# dtype: object
# 0    Day
# dtype: object
# 0    Day
# dtype: object
# 0    Day
# dtype: object

# %%
# X['Side'].fillna(str(X['Side'].mode().values[0]), inplace=True)
X['City'].fillna(str(X['City'].mode().values[0]), inplace=True) #or should these be dropped, only 83
X['State'].fillna(str(X['State'].mode().values[0]), inplace=True)
X['Weather_Timestamp'].fillna(str(X['Weather_Timestamp'].mode().values[0]), inplace=True)
X['Wind_Direction'].fillna(str(X['Wind_Direction'].mode().values[0]), inplace=True)
X['Weather_Condition'].fillna(str(X['Weather_Condition'].mode().values[0]), inplace=True)
X['Sunrise_Sunset'].fillna(str(X['Sunrise_Sunset'].mode().values[0]), inplace=True)
X['Civil_Twilight'].fillna(str(X['Civil_Twilight'].mode().values[0]), inplace=True)
X['Nautical_Twilight'].fillna(str(X['Nautical_Twilight'].mode().values[0]), inplace=True)
X['Astronomical_Twilight'].fillna(str(X['Astronomical_Twilight'].mode().values[0]), inplace=True)

# %%
#clean up time

X['Start_Time'] = pd.to_datetime(X['Start_Time'])
X['End_Time'] = pd.to_datetime(X['End_Time'])
X['Weather_Timestamp'] = pd.to_datetime(X['Weather_Timestamp'])

X['start_day'] = X['Start_Time'].dt.day.astype(np.int64)
X['start_weekday'] = X['Start_Time'].dt.weekday.astype(np.int64)
X['start_month'] = X['Start_Time'].dt.month.astype(np.int64)
X['start_hour'] = X['Start_Time'].dt.hour.astype(np.int64)
X['start_minute'] = X['Start_Time'].dt.minute.astype(np.int64)
X['start_second'] = X['Start_Time'].dt.second.astype(np.int64)

X['end_day'] = X['End_Time'].dt.day.astype(np.int64)
X['end_weekday'] = X['End_Time'].dt.weekday.astype(np.int64)
X['end_month'] = X['End_Time'].dt.month.astype(np.int64)
X['end_hour'] = X['End_Time'].dt.hour.astype(np.int64)
X['end_minute'] = X['End_Time'].dt.minute.astype(np.int64)
X['end_second'] = X['End_Time'].dt.second.astype(np.int64)

X['weather_day'] = X['Weather_Timestamp'].dt.day.astype(np.int64)
X['weather_weekday'] = X['Weather_Timestamp'].dt.weekday.astype(np.int64)
X['weather_month'] = X['Weather_Timestamp'].dt.month.astype(np.int64)
X['weather_hour'] = X['Weather_Timestamp'].dt.hour.astype(np.int64)
X['weather_minute'] = X['Weather_Timestamp'].dt.minute.astype(np.int64)
X['weather_second'] = X['Weather_Timestamp'].dt.second.astype(np.int64)

# X['duration'] = #TODO determine crash duration based on Start_Time and End_Time

X = X.drop(['Start_Time', 'End_Time', 'Weather_Timestamp'], 1)

# %%
X.isnull().sum()
# Out:
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# City                     0
# State                    0
# Temperature(F)           0
# Wind_Chill(F)            0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# Traffic_Calming          0
# Traffic_Signal           0
# Turning_Loop             0
# Sunrise_Sunset           0
# Civil_Twilight           0
# Nautical_Twilight        0
# Astronomical_Twilight    0
# start_day                0
# start_weekday            0
# start_month              0
# start_hour               0
# start_minute             0
# start_second             0
# end_day                  0
# end_weekday              0
# end_month                0
# end_hour                 0
# end_minute               0
# end_second               0
# weather_day              0
# weather_weekday          0
# weather_month            0
# weather_hour             0
# weather_minute           0
# weather_second           0
# dtype: int64

# %%
print(X.shape)
print(X.dtypes)
X.head()
# Out:
# (2974335, 49)
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# City                      object
# State                     object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# start_day                  int64
# start_weekday              int64
# start_month                int64
# start_hour                 int64
# start_minute               int64
# start_second               int64
# end_day                    int64
# end_weekday                int64
# end_month                  int64
# end_hour                   int64
# end_minute                 int64
# end_second                 int64
# weather_day                int64
# weather_weekday            int64
# weather_month              int64
# weather_hour               int64
# weather_minute             int64
# weather_second             int64
# dtype: object
#    Start_Lat  Start_Lng  Distance(mi)          City State  Temperature(F)  \
# 0  39.865147 -84.058723          0.01        Dayton    OH            36.9
# 1  39.928059 -82.831184          0.01  Reynoldsburg    OH            37.9
# 2  39.063148 -84.032608          0.01  Williamsburg    OH            36.0
# 3  39.747753 -84.205582          0.01        Dayton    OH            35.1
# 4  39.627781 -84.188354          0.01        Dayton    OH            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)       ...        \
# 0           54.0         91.0         29.68            10.0       ...
# 1           54.0        100.0         29.65            10.0       ...
# 2           33.3        100.0         29.67            10.0       ...
# 3           31.0         96.0         29.64             9.0       ...
# 4           33.3         89.0         29.65             6.0       ...
#
#   end_month  end_hour  end_minute end_second  weather_day  weather_weekday  \
# 0         2        11           0          0            8                0
# 1         2         6          37         59            8                0
# 2         2         7          19         27            8                0
# 3         2         7          53         34            8                0
# 4         2         8           9          7            8                0
#
#    weather_month  weather_hour  weather_minute  weather_second
# 0              2             5              58               0
# 1              2             5              51               0
# 2              2             6              56               0
# 3              2             7              38               0
# 4              2             7              53               0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Replace True/False and Categorical Features

# %%
#convert True/False to 1/0

#https://pbpython.com/categorical-encoding.html
#https://pbpython.com/categorical-encoding.html

boolean_features = list(X.select_dtypes(include=['bool']).columns)
print(boolean_features)
X[boolean_features] = X[boolean_features].astype(np.int64)
# Out:
# ['Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop']

# %%
print(X.dtypes)
# Out:
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# City                      object
# State                     object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                    int64
# Bump                       int64
# Crossing                   int64
# Give_Way                   int64
# Junction                   int64
# No_Exit                    int64
# Railway                    int64
# Roundabout                 int64
# Station                    int64
# Stop                       int64
# Traffic_Calming            int64
# Traffic_Signal             int64
# Turning_Loop               int64
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# start_day                  int64
# start_weekday              int64
# start_month                int64
# start_hour                 int64
# start_minute               int64
# start_second               int64
# end_day                    int64
# end_weekday                int64
# end_month                  int64
# end_hour                   int64
# end_minute                 int64
# end_second                 int64
# weather_day                int64
# weather_weekday            int64
# weather_month              int64
# weather_hour               int64
# weather_minute             int64
# weather_second             int64
# dtype: object

# %%
# encoding = {'Side': {'R': 0, 'L': 1}} #TODO there is a default value 
# temp = X.replace(encoding, inplace=False)

# print(temp.shape)
# print(temp.dtypes)
# temp.head()

# %%
#convert categorial data using One-Hot Encoding

one_hot_features = list(X.select_dtypes(include=['object']).columns)
print(one_hot_features)
one_hot_features.remove('City')
one_hot_features.remove('State')
print(one_hot_features)

print(X.shape)
# Out:
# ['City', 'State', 'Wind_Direction', 'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']
# ['Wind_Direction', 'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']
# (2974335, 49)

# %%
temp = pd.get_dummies(X, columns=one_hot_features) #TODO make int64
X = temp #fixes problem where only the one_hot_features are saved in the dataframe...

# %%
descriptors = ['City', 'State']
description = X['City']
description = np.reshape(description, (description.shape[0], 1))
print(description.shape)

X = X.drop(descriptors, 1)
# Out:
# C:\Users\alexa\AppData\Local\Programs\Python\Python36\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# (2974335, 1)

# %%
print(X.shape)

datatypes = dict(X.dtypes)
for k, v in datatypes.items():
    print('%55s - %s - %s' % (str(k), str(v), type(v)))
# Out:
# (2974335, 193)
#                                               Start_Lat - float64 - <class 'numpy.dtype'>
#                                               Start_Lng - float64 - <class 'numpy.dtype'>
#                                            Distance(mi) - float64 - <class 'numpy.dtype'>
#                                          Temperature(F) - float64 - <class 'numpy.dtype'>
#                                           Wind_Chill(F) - float64 - <class 'numpy.dtype'>
#                                             Humidity(%) - float64 - <class 'numpy.dtype'>
#                                            Pressure(in) - float64 - <class 'numpy.dtype'>
#                                          Visibility(mi) - float64 - <class 'numpy.dtype'>
#                                         Wind_Speed(mph) - float64 - <class 'numpy.dtype'>
#                                       Precipitation(in) - float64 - <class 'numpy.dtype'>
#                                                 Amenity - int64 - <class 'numpy.dtype'>
#                                                    Bump - int64 - <class 'numpy.dtype'>
#                                                Crossing - int64 - <class 'numpy.dtype'>
#                                                Give_Way - int64 - <class 'numpy.dtype'>
#                                                Junction - int64 - <class 'numpy.dtype'>
#                                                 No_Exit - int64 - <class 'numpy.dtype'>
#                                                 Railway - int64 - <class 'numpy.dtype'>
#                                              Roundabout - int64 - <class 'numpy.dtype'>
#                                                 Station - int64 - <class 'numpy.dtype'>
#                                                    Stop - int64 - <class 'numpy.dtype'>
#                                         Traffic_Calming - int64 - <class 'numpy.dtype'>
#                                          Traffic_Signal - int64 - <class 'numpy.dtype'>
#                                            Turning_Loop - int64 - <class 'numpy.dtype'>
#                                               start_day - int64 - <class 'numpy.dtype'>
#                                           start_weekday - int64 - <class 'numpy.dtype'>
#                                             start_month - int64 - <class 'numpy.dtype'>
#                                              start_hour - int64 - <class 'numpy.dtype'>
#                                            start_minute - int64 - <class 'numpy.dtype'>
#                                            start_second - int64 - <class 'numpy.dtype'>
#                                                 end_day - int64 - <class 'numpy.dtype'>
#                                             end_weekday - int64 - <class 'numpy.dtype'>
#                                               end_month - int64 - <class 'numpy.dtype'>
#                                                end_hour - int64 - <class 'numpy.dtype'>
#                                              end_minute - int64 - <class 'numpy.dtype'>
#                                              end_second - int64 - <class 'numpy.dtype'>
#                                             weather_day - int64 - <class 'numpy.dtype'>
#                                         weather_weekday - int64 - <class 'numpy.dtype'>
#                                           weather_month - int64 - <class 'numpy.dtype'>
#                                            weather_hour - int64 - <class 'numpy.dtype'>
#                                          weather_minute - int64 - <class 'numpy.dtype'>
#                                          weather_second - int64 - <class 'numpy.dtype'>
#                                     Wind_Direction_CALM - uint8 - <class 'numpy.dtype'>
#                                     Wind_Direction_Calm - uint8 - <class 'numpy.dtype'>
#                                        Wind_Direction_E - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_ENE - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_ESE - uint8 - <class 'numpy.dtype'>
#                                     Wind_Direction_East - uint8 - <class 'numpy.dtype'>
#                                        Wind_Direction_N - uint8 - <class 'numpy.dtype'>
#                                       Wind_Direction_NE - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_NNE - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_NNW - uint8 - <class 'numpy.dtype'>
#                                       Wind_Direction_NW - uint8 - <class 'numpy.dtype'>
#                                    Wind_Direction_North - uint8 - <class 'numpy.dtype'>
#                                        Wind_Direction_S - uint8 - <class 'numpy.dtype'>
#                                       Wind_Direction_SE - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_SSE - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_SSW - uint8 - <class 'numpy.dtype'>
#                                       Wind_Direction_SW - uint8 - <class 'numpy.dtype'>
#                                    Wind_Direction_South - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_VAR - uint8 - <class 'numpy.dtype'>
#                                 Wind_Direction_Variable - uint8 - <class 'numpy.dtype'>
#                                        Wind_Direction_W - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_WNW - uint8 - <class 'numpy.dtype'>
#                                      Wind_Direction_WSW - uint8 - <class 'numpy.dtype'>
#                                     Wind_Direction_West - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Blowing Dust - uint8 - <class 'numpy.dtype'>
#                  Weather_Condition_Blowing Dust / Windy - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Blowing Sand - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Blowing Snow - uint8 - <class 'numpy.dtype'>
#                  Weather_Condition_Blowing Snow / Windy - uint8 - <class 'numpy.dtype'>
#                                 Weather_Condition_Clear - uint8 - <class 'numpy.dtype'>
#                                Weather_Condition_Cloudy - uint8 - <class 'numpy.dtype'>
#                        Weather_Condition_Cloudy / Windy - uint8 - <class 'numpy.dtype'>
#                               Weather_Condition_Drizzle - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_Drizzle / Windy - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_Drizzle and Fog - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Dust Whirls - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Fair - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Fair / Windy - uint8 - <class 'numpy.dtype'>
#                                   Weather_Condition_Fog - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Fog / Windy - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Freezing Rain - uint8 - <class 'numpy.dtype'>
#                 Weather_Condition_Freezing Rain / Windy - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Funnel Cloud - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Hail - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Haze - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Haze / Windy - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Heavy Blowing Snow - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Heavy Drizzle - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Heavy Freezing Drizzle - uint8 - <class 'numpy.dtype'>
#                   Weather_Condition_Heavy Freezing Rain - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Heavy Ice Pellets - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Heavy Rain - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Heavy Rain / Windy - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Heavy Rain Showers - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Heavy Sleet - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Heavy Smoke - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Heavy Snow - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Heavy Snow / Windy - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Heavy Snow with Thunder - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Heavy T-Storm - uint8 - <class 'numpy.dtype'>
#                 Weather_Condition_Heavy T-Storm / Windy - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Heavy Thunderstorms and Rain - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Heavy Thunderstorms and Snow - uint8 - <class 'numpy.dtype'>
#   Weather_Condition_Heavy Thunderstorms with Small Hail - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Ice Pellets - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Blowing Snow - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Light Drizzle - uint8 - <class 'numpy.dtype'>
#                 Weather_Condition_Light Drizzle / Windy - uint8 - <class 'numpy.dtype'>
#                             Weather_Condition_Light Fog - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Light Freezing Drizzle - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Freezing Fog - uint8 - <class 'numpy.dtype'>
#                   Weather_Condition_Light Freezing Rain - uint8 - <class 'numpy.dtype'>
#           Weather_Condition_Light Freezing Rain / Windy - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Light Hail - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Light Haze - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Light Ice Pellets - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Light Rain - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Rain / Windy - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Light Rain Shower - uint8 - <class 'numpy.dtype'>
#             Weather_Condition_Light Rain Shower / Windy - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Rain Showers - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Light Rain with Thunder - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Light Sleet - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Light Snow - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Snow / Windy - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Light Snow Grains - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Light Snow Shower - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Snow Showers - uint8 - <class 'numpy.dtype'>
#                  Weather_Condition_Light Snow and Sleet - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Light Snow and Sleet / Windy - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Light Snow with Thunder - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Light Thunderstorm - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Light Thunderstorms and Rain - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Light Thunderstorms and Snow - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_Low Drifting Snow - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Mist - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Mostly Cloudy - uint8 - <class 'numpy.dtype'>
#                 Weather_Condition_Mostly Cloudy / Windy - uint8 - <class 'numpy.dtype'>
#                     Weather_Condition_N/A Precipitation - uint8 - <class 'numpy.dtype'>
#                              Weather_Condition_Overcast - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Partial Fog - uint8 - <class 'numpy.dtype'>
#                   Weather_Condition_Partial Fog / Windy - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Partly Cloudy - uint8 - <class 'numpy.dtype'>
#                 Weather_Condition_Partly Cloudy / Windy - uint8 - <class 'numpy.dtype'>
#                        Weather_Condition_Patches of Fog - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Rain - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Rain / Windy - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Rain Shower - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Rain Showers - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Sand - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Sand / Dust Whirlwinds - uint8 - <class 'numpy.dtype'>
#        Weather_Condition_Sand / Dust Whirlwinds / Windy - uint8 - <class 'numpy.dtype'>
#                      Weather_Condition_Scattered Clouds - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Shallow Fog - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Showers in the Vicinity - uint8 - <class 'numpy.dtype'>
#                                 Weather_Condition_Sleet - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Small Hail - uint8 - <class 'numpy.dtype'>
#                                 Weather_Condition_Smoke - uint8 - <class 'numpy.dtype'>
#                         Weather_Condition_Smoke / Windy - uint8 - <class 'numpy.dtype'>
#                                  Weather_Condition_Snow - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Snow / Windy - uint8 - <class 'numpy.dtype'>
#                           Weather_Condition_Snow Grains - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Snow Showers - uint8 - <class 'numpy.dtype'>
#                        Weather_Condition_Snow and Sleet - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Snow and Sleet / Windy - uint8 - <class 'numpy.dtype'>
#                      Weather_Condition_Snow and Thunder - uint8 - <class 'numpy.dtype'>
#                               Weather_Condition_Squalls - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_Squalls / Windy - uint8 - <class 'numpy.dtype'>
#                               Weather_Condition_T-Storm - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_T-Storm / Windy - uint8 - <class 'numpy.dtype'>
#                               Weather_Condition_Thunder - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_Thunder / Windy - uint8 - <class 'numpy.dtype'>
#          Weather_Condition_Thunder / Wintry Mix / Windy - uint8 - <class 'numpy.dtype'>
#              Weather_Condition_Thunder and Hail / Windy - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Thunder in the Vicinity - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Thunderstorm - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Thunderstorms and Rain - uint8 - <class 'numpy.dtype'>
#                Weather_Condition_Thunderstorms and Snow - uint8 - <class 'numpy.dtype'>
#                               Weather_Condition_Tornado - uint8 - <class 'numpy.dtype'>
#                          Weather_Condition_Volcanic Ash - uint8 - <class 'numpy.dtype'>
#                       Weather_Condition_Widespread Dust - uint8 - <class 'numpy.dtype'>
#               Weather_Condition_Widespread Dust / Windy - uint8 - <class 'numpy.dtype'>
#                            Weather_Condition_Wintry Mix - uint8 - <class 'numpy.dtype'>
#                    Weather_Condition_Wintry Mix / Windy - uint8 - <class 'numpy.dtype'>
#                                      Sunrise_Sunset_Day - uint8 - <class 'numpy.dtype'>
#                                    Sunrise_Sunset_Night - uint8 - <class 'numpy.dtype'>
#                                      Civil_Twilight_Day - uint8 - <class 'numpy.dtype'>
#                                    Civil_Twilight_Night - uint8 - <class 'numpy.dtype'>
#                                   Nautical_Twilight_Day - uint8 - <class 'numpy.dtype'>
#                                 Nautical_Twilight_Night - uint8 - <class 'numpy.dtype'>
#                               Astronomical_Twilight_Day - uint8 - <class 'numpy.dtype'>
#                             Astronomical_Twilight_Night - uint8 - <class 'numpy.dtype'>

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

print('X:', X.shape)

num_features = 20
num_components = num_features

feature_names = X.columns
print('Using features %s through %s' % (feature_names[0],feature_names[num_features-1]))

X_fit = sc.fit_transform(X.loc[:, feature_names[0]:feature_names[num_features-1]])
# X_fit = sc.fit_transform(X.loc[:, 'Distance(mi)':'Stop'])
pca = PCA(n_components=num_components) #tcga on this
X_pca = pca.fit_transform(X_fit)
# Out:
# X: (2974335, 193)
# Using features Start_Lat through Stop

# %%
explained_variance = pca.explained_variance_ratio_

print('Explained Variance: %s' % (explained_variance))
print('Total Explained Variance: %s' % (np.sum(explained_variance)))
# Out:
# Explained Variance: [0.1134558  0.07337106 0.06670559 0.05833013 0.05348781 0.05170757
#  0.0510507  0.05096034 0.05033894 0.04985719 0.04934995 0.04887753
#  0.04742582 0.04631021 0.04158561 0.04038695 0.03540753 0.03264594
#  0.02765773 0.01108761]
# Total Explained Variance: 1.0

# %%
ax = plt.figure()
plt.xlabel('Component #')
plt.ylabel('Explained Variance')
plt.scatter(range(0, num_components), explained_variance)
